# %%
import os
import json
import streamlit as st
import mysql.connector as mysql
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
def state_name_format(state_name):
    state_name = state_name.replace("-"," ")
    return state_name.title()

# %%
#This is to direct the path to get the data as states

Agg_Transaction_path="/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/aggregated/transaction/country/india/state/"
Agg_states_list=os.listdir(Agg_Transaction_path)
#print(Agg_states_list)

Agg_user_path = "/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/aggregated/user/country/india/state/"
Agg_users_list = os.listdir(Agg_user_path)
print(Agg_users_list)
#This is to extract the data's to create a dataframe

Agg_states_data = {'State':[], 'Year':[], 'Quarter':[], 'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

def Agg_detail_states_list(state_list):
    for i in state_list:
        country_name = Agg_Transaction_path+i+"/"
        try:
            select_years_list = os.listdir(country_name)
            for j in select_years_list:
                year_path = country_name+j+"/"
                Agg_year_list = os.listdir(year_path)
                for k in Agg_year_list:
                    selected_year = year_path+k
                    data = open(selected_year,'r')
                    json_data = json.load(data)

                    transactionData = json_data['data']['transactionData']
                    #print("transactionData.........",transactionData)
                    for details in transactionData:
                        name = details['name']
                        count = details['paymentInstruments'][0]['count']
                        amount = details['paymentInstruments'][0]['amount']
                        #print('name......',name)

                        Agg_states_data['Transaction_type'].append(name)
                        Agg_states_data['Transaction_count'].append(count)
                        Agg_states_data['Transaction_amount'].append(amount)
                        Agg_states_data['State'].append(state_name_format(i))
                        Agg_states_data['Year'].append(j)
                        Agg_states_data['Quarter'].append(int(k.strip('.json')))
                        
                        
            Agg_Trans_df =pd.DataFrame(Agg_states_data)
        except:
            pass
        finally:
            data.close()
    return Agg_Trans_df

#Agg_detail_states_list(Agg_states_list)
# Out:
# ['andaman-&-nicobar-islands', 'tamil-nadu', 'lakshadweep', 'telangana', 'manipur', 'haryana', 'gujarat', 'sikkim', 'delhi', 'west-bengal', 'uttar-pradesh', 'goa', 'punjab', 'arunachal-pradesh', 'karnataka', 'jammu-&-kashmir', 'maharashtra', 'odisha', 'madhya-pradesh', 'rajasthan', 'andhra-pradesh', 'chandigarh', 'kerala', 'chhattisgarh', 'tripura', 'mizoram', 'himachal-pradesh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'ladakh', 'assam', 'meghalaya', 'uttarakhand', 'puducherry', 'bihar', 'jharkhand', 'nagaland']

# %%
Agg_Trans_df =pd.DataFrame(Agg_states_data)
Agg_Trans_df
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     Andaman & Nicobar Islands  2022        1     Peer-to-peer payments
# 1     Andaman & Nicobar Islands  2022        1         Merchant payments
# 2     Andaman & Nicobar Islands  2022        1  Recharge & bill payments
# 3     Andaman & Nicobar Islands  2022        1        Financial Services
# 4     Andaman & Nicobar Islands  2022        1                    Others
# ...                         ...   ...      ...                       ...
# 4489                   Nagaland  2018        4  Recharge & bill payments
# 4490                   Nagaland  2018        4     Peer-to-peer payments
# 4491                   Nagaland  2018        4         Merchant payments
# 4492                   Nagaland  2018        4        Financial Services
# 4493                   Nagaland  2018        4                    Others
#
#       Transaction_count  Transaction_amount
# 0                342649        1.682329e+09
# ...

# %%
 # %matplotlib inline 
sns.boxplot(Agg_Trans['Transaction_amount'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 sns.boxplot(Agg_Trans['Transaction_amount'])
#       3 plt.show()
#
# NameError: name 'Agg_Trans' is not defined

# %%
#normalization
# cols=['Transaction_count','Transaction_amount']

# for col in cols:
#     Agg_Trans[col] = (Agg_Trans[col]-Agg_Trans[col].min())/(Agg_Trans[col].max()-Agg_Trans[col].min())
# Agg_Trans

# %%
# %matplotlib inline 
# sns.boxplot(Agg_Trans['Transaction_amount'])
# plt.show()

# %%
#  %matplotlib inline 
# sns.boxplot(Agg_Trans['Transaction_count'])
# plt.show()

# %%
#standadization
# cols = ['Transaction_count','Transaction_amount']

# for col in cols:
#     Agg_Trans[col] = (Agg_Trans[col] - Agg_Trans[col].mean())/(Agg_Trans[col].std())
# Agg_Trans

# %%
# %matplotlib inline 
# sns.boxplot(Agg_Trans['Transaction_amount'])
# plt.show()

# %%
Agg_user_path = "/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/aggregated/user/country/india/state/"
Agg_users_list = os.listdir(Agg_user_path)
#print(Agg_users_list)

# %%
Agg_users_data = {'State':[], 'Year':[], 'Quarter':[], 'Brand':[], 'Count':[], 'Percentage':[]}

# %%
def Agg_user_list(user_list):
    for i in user_list:
        user_state = Agg_user_path + i+"/"
        #print('user_state.....', user_state)
        try:
            user_year_list = os.listdir(user_state)
            for j in user_year_list:
                #print('j....',j)
                user_year = user_state+j+"/"
                selected_year_list = os.listdir(user_year)
                for k in selected_year_list:
                    #print('k......',k)
                    selected_year = user_year+k
                    data = open(selected_year,"r")
                    user_json = json.load(data)

                    userData = user_json['data']['usersByDevice']
                    #print('userdata.......',userData)

                    if userData:
                        for details in userData:
                            brand = details['brand']
                            count = details['count']
                            percentage = details['percentage']

                            Agg_users_data['Brand'].append(brand)
                            Agg_users_data['Count'].append(count)
                            Agg_users_data['Percentage'].append(percentage)
                            Agg_users_data['State'].append(state_name_format(i))
                            Agg_users_data['Year'].append(j)
                            Agg_users_data['Quarter'].append(int(k.strip('.json')))
                            
                    
            Agg_user_df = pd.DataFrame(Agg_users_data)

        except:
            pass
        
        finally:
            data.close()
            

    return Agg_user_df
                    
#Agg_user_df = Agg_user_list(Agg_users_list)
#print('agg user....',Agg_user)

# %%
Agg_user_df
# Out:
#                            State  Year  Quarter    Brand  Count  Percentage
# 0      Andaman & Nicobar Islands  2022        1     Vivo  18688    0.244966
# 1      Andaman & Nicobar Islands  2022        1   Xiaomi  17957    0.235384
# 2      Andaman & Nicobar Islands  2022        1  Samsung  12955    0.169817
# 3      Andaman & Nicobar Islands  2022        1   Realme   6769    0.088730
# 4      Andaman & Nicobar Islands  2022        1     Oppo   6461    0.084692
# ...                          ...   ...      ...      ...    ...         ...
# 13107                   Nagaland  2018        4    Apple   1148    0.026700
# 13108                   Nagaland  2018        4   Lenovo   1024    0.023816
# 13109                   Nagaland  2018        4   Huawei    849    0.019746
# 13110                   Nagaland  2018        4     Asus    840    0.019536
# 13111                   Nagaland  2018        4   Others   6249    0.145336
#
# [13112 rows x 6 columns]

# %%
Map_trans_path ="/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/map/transaction/hover/country/india/state/"
Map_trans_list = os.listdir(Map_trans_path)
#print('Map_trans_list......',Map_trans_list)

# %%
Map_trans_data = {'State': [], 'Year': [], 'Quarter': [], 'Name': [], 'Type': [],'Count': [], 'Amount':[]}

# %%
def Map_transaction_list(trans_data):
    #print('trans_data========',trans_data)
    for i in trans_data:
        #print('i......',i)
        trans_name = Map_trans_path+i+"/"
        try:
            trans_year_list = os.listdir(trans_name)
            for j in trans_year_list:
               # print('j......',j)
                trans_year = trans_name+j+"/"
                selected_year_list = os.listdir(trans_year)
                for k in selected_year_list:
                    #print('k.........',k)
                    selected_year = trans_year+k
                    data = open(selected_year,'r')
                    map_trans_json = json.load(data)
                    
                    map_transaction_data = map_trans_json['data']['hoverDataList']
                    #print('map_transaction_data........',map_transaction_data)
                    for details in map_transaction_data:
                        name = details['name']
                        Type = details['metric'][0]['type']
                        count = details['metric'][0]['count']
                        amount = details['metric'][0]['amount']
                        
                        Map_trans_data['Name'].append(name)
                        Map_trans_data['Type'].append(Type)
                        Map_trans_data['Count'].append(count)
                        Map_trans_data['Amount'].append(amount)
                        Map_trans_data['State'].append(state_name_format(i))
                        Map_trans_data['Year'].append(j)
                        Map_trans_data['Quarter'].append(int(k.strip('.json')))
                        
                        
            map_trans_df = pd.DataFrame(Map_trans_data)
        except:
            pass
        
        finally:
            data.close()
                  
                        
    return map_trans_df

#map_trans_details = Map_transaction_list(Map_trans_list)
#print('map_trans_details.......',map_trans_details)

# %%
map_trans_df = pd.DataFrame(map_trans_details)
map_trans_df
# Out:
#                            State  Year  Quarter  \
# 0      Andaman & Nicobar Islands  2022        1
# 1      Andaman & Nicobar Islands  2022        1
# 2      Andaman & Nicobar Islands  2022        1
# 3      Andaman & Nicobar Islands  2022        2
# 4      Andaman & Nicobar Islands  2022        2
# ...                          ...   ...      ...
# 36587                   Nagaland  2018        4
# 36588                   Nagaland  2018        4
# 36589                   Nagaland  2018        4
# 36590                   Nagaland  2018        4
# 36591                   Nagaland  2018        4
#
#                                     Name   Type   Count        Amount
# 0      north and middle andaman district  TOTAL   60059  1.616249e+08
# 1                 south andaman district  TOTAL  705512  1.872991e+09
# 2                      nicobars district  TOTAL   29177  9.441413e+07
# 3      north and middle andaman district  TOTAL   72573  1.956932e+08
# ...

# %%
Map_user_path = "/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/map/user/hover/country/india/state/"
Map_user_list = os.listdir(Map_user_path)
#print('Map_user_list........',Map_user_list)
# Out:
# Map_user_list........ ['andaman-&-nicobar-islands', 'tamil-nadu', 'lakshadweep', 'telangana', 'manipur', 'haryana', 'gujarat', 'sikkim', 'delhi', 'west-bengal', 'uttar-pradesh', 'goa', 'punjab', 'arunachal-pradesh', 'karnataka', 'jammu-&-kashmir', 'maharashtra', 'odisha', 'madhya-pradesh', 'rajasthan', 'andhra-pradesh', 'chandigarh', 'kerala', 'chhattisgarh', 'tripura', 'mizoram', 'himachal-pradesh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'ladakh', 'assam', 'meghalaya', 'uttarakhand', 'puducherry', 'bihar', 'jharkhand', 'nagaland']

# %%
Map_Users_Data = {'State':[],'Year':[],'Quarter':[],'Name':[],'RegisteredUsers':[],'AppOpens':[]}

# %%
def Map_users_list(map_users):
    for i in map_users:
        map_user_state = Map_user_path+i+"/"
        try:
            map_user_years = os.listdir(map_user_state)
            for j in map_user_years:
                user_years = map_user_state + j+"/"
                years_list =  os.listdir(user_years)
                for k in years_list:
                    selected_year =  user_years+k
                    data = open(selected_year,'r')
                    map_user_json = json.load(data)
                    
                    map_user_data = map_user_json['data']['hoverData'].items()
                    for details in map_user_data:
                        district = details[0]
                        registered_users = details[1]['registeredUsers']
                        app_opens = details[1]['appOpens']
                        
                        
                        Map_Users_Data['Name'].append(district)
                        Map_Users_Data['RegisteredUsers'].append(registered_users)
                        Map_Users_Data['AppOpens'].append(app_opens)
                        Map_Users_Data['State'].append(state_name_format(i))
                        Map_Users_Data['Year'].append(j)
                        Map_Users_Data['Quarter'].append(int(k.strip('.json')))
                        
            map_user_df = pd.DataFrame(Map_Users_Data)
                        
        except:
            pass
        
        finally:
            data.close()
            
                        
    return map_user_df

#map_user_details = Map_users_list(Map_user_list)
#print(map_user_details)

# %%
map_user_df = pd.DataFrame(map_user_details)
map_user_df
# Out:
#                            State  Year  Quarter  \
# 0      Andaman & Nicobar Islands  2022        1
# 1      Andaman & Nicobar Islands  2022        1
# 2      Andaman & Nicobar Islands  2022        1
# 3      Andaman & Nicobar Islands  2022        2
# 4      Andaman & Nicobar Islands  2022        2
# ...                          ...   ...      ...
# 36595                   Nagaland  2018        4
# 36596                   Nagaland  2018        4
# 36597                   Nagaland  2018        4
# 36598                   Nagaland  2018        4
# 36599                   Nagaland  2018        4
#
#                                     Name  RegisteredUsers  AppOpens
# 0      north and middle andaman district            10720    904869
# 1                 south andaman district            63487   2368756
# 2                      nicobars district             2081    573782
# 3      north and middle andaman district            11379    963824
# ...

# %%
Top_transaction_path = "/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/top/transaction/country/india/state/"
Top_transaction_list = os.listdir(Top_transaction_path)
#print(Top_transaction_list)
# Out:
# ['andaman-&-nicobar-islands', 'tamil-nadu', 'lakshadweep', 'telangana', 'manipur', 'haryana', 'gujarat', 'sikkim', 'delhi', 'west-bengal', 'uttar-pradesh', 'goa', 'punjab', 'arunachal-pradesh', 'karnataka', 'jammu-&-kashmir', 'maharashtra', 'odisha', 'madhya-pradesh', 'rajasthan', 'andhra-pradesh', 'chandigarh', 'kerala', 'chhattisgarh', 'tripura', 'mizoram', 'himachal-pradesh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'ladakh', 'assam', 'meghalaya', 'uttarakhand', 'puducherry', 'bihar', 'jharkhand', 'nagaland']

# %%
def load_top_trans_data():
        top_trans_district=[]
        top_trans_pincode=[]
        for state in Top_transaction_list:
            try:
                year_path=Top_transaction_path+state+'/'
                year_list=os.listdir(year_path)
                for year in year_list:
                    quarter_path=year_path+year+'/'
                    quarter_list=os.listdir(quarter_path)
                    for file in quarter_list:
                        file_path=quarter_path+file
                        file_opened=open(file_path,'r')
                        data=json.load(file_opened)
                        #print('data.......',data)

                        for district in data['data']['districts']:
                            quarter=int(file.strip('.json'))
                            top_trans_district.append({
                                'District':district.get('entityName','NA'),
                                'Count':district['metric'].get('count', 0),
                                'Amount':district['metric'].get('amount', 0),
                                'State':state_name_format(state),
                                'Year':year,
                                'Quarter':quarter
                            })

                        for pincode in data['data']['pincodes']:
                            quarter=int(file.strip('.json'))
                            top_trans_pincode.append({
                                'Pincode':pincode.get('entityName','NA'),
                                'Count':pincode['metric'].get('count', 0),
                                'Amount':pincode['metric'].get('amount', 0),
                                'State':state_name_format(state),
                                'Year':year,
                                'Quarter':quarter

                            })
            except:
                pass
            finally:
                file_opened.close()
                
            
        top_trans_district_df=pd.DataFrame(top_trans_district)
        top_trans_district_df['Amount']=top_trans_district_df['Amount'].apply(lambda x: round(x,2))
        top_trans_pincode_df=pd.DataFrame(top_trans_pincode)
        top_trans_pincode_df['Amount']=top_trans_pincode_df['Amount'].apply(lambda x: round(x,2))

        return top_trans_district_df,top_trans_pincode_df

# %%
top_trans_district_df,top_trans_pincode_df = load_top_trans_data()

# %%
top_trans_district_df
# Out:
#                       District   Count        Amount  \
# 0                south andaman  705512  1.872991e+09
# 1     north and middle andaman   60059  1.616249e+08
# 2                     nicobars   29177  9.441413e+07
# 3                south andaman  954875  2.357327e+09
# 4     north and middle andaman   72573  1.956932e+08
# ...                        ...     ...           ...
# 7235                 zunheboto    4966  1.244903e+07
# 7236                     wokha    4959  8.954847e+06
# 7237                      phek    3615  6.547794e+06
# 7238                     peren    2071  6.712395e+06
# 7239                   kiphire    2008  3.577703e+06
#
#                           State  Year  Quarter
# 0     Andaman & Nicobar Islands  2022        1
# 1     Andaman & Nicobar Islands  2022        1
# 2     Andaman & Nicobar Islands  2022        1
# 3     Andaman & Nicobar Islands  2022        2
# 4     Andaman & Nicobar Islands  2022        2
# ...

# %%
top_trans_pincode_df
# Out:
#      Pincode   Count        Amount                      State  Year  Quarter
# 0     744101  209941  6.159781e+08  Andaman & Nicobar Islands  2022        1
# 1     744103  157230  3.997160e+08  Andaman & Nicobar Islands  2022        1
# 2     744105  122716  3.218506e+08  Andaman & Nicobar Islands  2022        1
# 3     744102   74883  1.933365e+08  Andaman & Nicobar Islands  2022        1
# 4     744104   32471  7.291552e+07  Andaman & Nicobar Islands  2022        1
# ...      ...     ...           ...                        ...   ...      ...
# 8759  797113    5861  1.606055e+07                   Nagaland  2018        4
# 8760  798601    5806  1.207269e+07                   Nagaland  2018        4
# 8761  797117    4640  1.411745e+07                   Nagaland  2018        4
# 8762  797118    4531  1.615445e+07                   Nagaland  2018        4
# 8763  797116    4309  1.336502e+07                   Nagaland  2018        4
#
# [8764 rows x 6 columns]

# %%
Top_users_path = "/Users/upendra/Desktop/Capstone_Projets/PhonePe/data/data/top/user/country/india/state/"
Top_users_list = os.listdir(Top_users_path)
#print(Top_users_list)
# Out:
# ['andaman-&-nicobar-islands', 'tamil-nadu', 'lakshadweep', 'telangana', 'manipur', 'haryana', 'gujarat', 'sikkim', 'delhi', 'west-bengal', 'uttar-pradesh', 'goa', 'punjab', 'arunachal-pradesh', 'karnataka', 'jammu-&-kashmir', 'maharashtra', 'odisha', 'madhya-pradesh', 'rajasthan', 'andhra-pradesh', 'chandigarh', 'kerala', 'chhattisgarh', 'tripura', 'mizoram', 'himachal-pradesh', 'dadra-&-nagar-haveli-&-daman-&-diu', 'ladakh', 'assam', 'meghalaya', 'uttarakhand', 'puducherry', 'bihar', 'jharkhand', 'nagaland']

# %%
def load_top_user_data():
    top_user_districts = []
    top_user_pincodes = []
    for state in Top_users_list:
        try:
            year_path = Top_users_path+state+"/"
            year_list = os.listdir(year_path)
            for year in year_list:
                quarter_path = year_path+year+"/"
                quarter_list = os.listdir(quarter_path)
                for quarter in quarter_list:
                    #print('quarter..........',quarter)
                    selected_quarter = quarter_path+quarter
                    
                    data = open(selected_quarter,'r')
                    top_user_json = json.load(data)
                    
                    for district in top_user_json['data']['districts']:
                        quarter_num=int(quarter.strip('.json'))
                        top_user_districts.append({
                                'District':district.get('name','NA'),
                                'RegisteredUsers':district.get('registeredUsers', 0),
                                'State':state_name_format(state),
                                'Year':year,
                                'Quarter':quarter_num      
                        })
                    
                    
                   # print('top_user_json pincodes.......',len(top_user_json['data']['pincodes']))
                    for pincode in top_user_json['data']['pincodes']:
                        #print(pincode)
                        quarter_num=int(quarter.strip('.json'))
                        top_user_pincodes.append({
                                'Pincode':pincode.get('name','NA'),
                                'RegisteredUsers':pincode.get('registeredUsers', 0),
                                'State':state_name_format(state),
                                'Year':year,
                                'Quarter':quarter_num      
                        })
        except Exception as err:
            print(err)
            pass
        finally:
            data.close()
        
    top_user_districts_df = pd.DataFrame(top_user_districts)
    top_user_pincodes_df = pd.DataFrame(top_user_pincodes)
    
    return top_user_districts_df,top_user_pincodes_df

# %%
top_user_districts_df,top_user_pincodes_df = load_top_user_data()

# %%
top_user_districts_df
# Out:
#                       District  RegisteredUsers  \
# 0                south andaman            63487
# 1                      chennai          2388315
# 2                  lakshadweep             5990
# 3                    hyderabad          4306136
# 4                  imphal west           125131
# 5                     gurugram          2929873
# 6                    ahmadabad          3897869
# 7                         east           120360
# 8                         west          2017435
# 9   north twenty four parganas          3224459
# 10         gautam buddha nagar          2822463
# 11                   north goa           456250
# 12                    ludhiana          1476288
# 13                  papum pare           111271
# 14             bengaluru urban         12707664
# 15                       jammu           401675
# 16                        pune          8331582
# 17                     khordha          1827307
# ...

# %%
top_user_pincodes_df
# Out:
#      Pincode  RegisteredUsers                      State  Year  Quarter
# 0     744103            15011  Andaman & Nicobar Islands  2022        1
# 1     744105            13070  Andaman & Nicobar Islands  2022        1
# 2     744101            12300  Andaman & Nicobar Islands  2022        1
# 3     744102             8271  Andaman & Nicobar Islands  2022        1
# 4     744202             4107  Andaman & Nicobar Islands  2022        1
# ...      ...              ...                        ...   ...      ...
# 8920  797120             2071                   Nagaland  2018        4
# 8921  798601             1972                   Nagaland  2018        4
# 8922  797117             1752                   Nagaland  2018        4
# 8923  797118             1604                   Nagaland  2018        4
# 8924  797116             1410                   Nagaland  2018        4
#
# [8925 rows x 5 columns]

# %%
def load_phopedata_mysql():
    try:
        mydb = mysql.connect(
            host = '127.0.0.1',
            user = 'root',
            password = '12345678',
            database = 'Phone_pe'
        )
        cursor = mydb.cursor()

        engine = create_engine('mysql+mysqlconnector://root:12345678@127.0.0.1/Phone_pe', echo=True)

        Agg_trans_df = Agg_detail_states_list(Agg_states_list)
        #Agg_states_df
        Agg_users_df =  Agg_user_list(Agg_users_list)
        #Agg_users_df
        map_trans_df = Map_transaction_list(Map_trans_list)
        #map_trans_df
        map_user_df = Map_users_list(Map_user_list)
        #map_user_df
        top_trans_district_df,top_trans_pincode_df = load_top_trans_data()
        #top_trans_district_df
        #top_trans_pincode_df
        top_user_districts_df,top_user_pincodes_df = load_top_user_data()
        #top_user_districts_df
        #top_user_pincodes_df
    
        Agg_trans_df.to_sql("agg_trans", engine, if_exists="replace", index=False)
        map_trans_df.to_sql("map_trans", engine, if_exists="replace", index=False)
        top_trans_district_df.to_sql("top_trans_district", engine, if_exists="replace", index=False)
        top_trans_pincode_df.to_sql("top_trans_pincode", engine, if_exists="replace", index=False)
        Agg_users_df.to_sql("agg_user",engine,if_exists="replace",index=False)
        map_user_df.to_sql("map_user",engine,if_exists="replace",index=False)
        top_user_districts_df.to_sql("top_user_district",engine,if_exists="replace",index=False)
        top_user_pincodes_df.to_sql("top_user_pincode",engine,if_exists="replace",index=False)
        cursor.close()
        mydb.close()
        return 'Data Loaded Sucessfully'
    except Exception as e:
        return e
if __name__ == "__main__":
    load_phopedata_mysql()
# Out:
# 2024-05-14 01:22:53,732 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-05-14 01:22:53,732 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-14 01:22:53,733 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-05-14 01:22:53,733 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-14 01:22:53,734 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-05-14 01:22:53,734 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-14 01:22:53,735 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-14 01:22:53,737 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2024-05-14 01:22:53,738 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {'table_schema': 'phone_pe', 'table_name': 'agg_trans'}
# 2024-05-14 01:22:53,739 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# ...

# %%
load_phopedata_mysql()
# Out:
# 2024-05-14 01:23:11,655 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-05-14 01:23:11,655 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-14 01:23:11,656 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-05-14 01:23:11,656 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-14 01:23:11,657 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-05-14 01:23:11,657 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-05-14 01:23:11,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-05-14 01:23:11,660 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2024-05-14 01:23:11,660 INFO sqlalchemy.engine.Engine [generated in 0.00041s] {'table_schema': 'phone_pe', 'table_name': 'agg_trans'}
# 2024-05-14 01:23:11,663 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# ...

# %%
Agg_trans_df = Agg_detail_states_list(Agg_states_list)
#Agg_states_df
Agg_users_df =  Agg_user_list(Agg_users_list)
#Agg_users_df
map_trans_df = Map_transaction_list(Map_trans_list)
#map_trans_df
map_user_df = Map_users_list(Map_user_list)
#map_user_df
top_trans_district_df,top_trans_pincode_df = load_top_trans_data()
#top_trans_district_df
#top_trans_pincode_df
top_user_districts_df,top_user_pincodes_df = load_top_user_data()
#top_user_districts_df
#top_user_pincodes_df
